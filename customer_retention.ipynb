# %% [raw]
# Name: Priti Chauhan
# Batch: 1845
# Internship: 32

# %% [markdown]
# *E-retail factors for customer activation and retention: A case study from Indian e-commerce customers*
# Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store; it has been posited as a key stimulant of purchase, repurchase intentions and customer loyalty. A comprehensive review of the literature, theories and models have been carried out to propose the models for customer activation and customer retention.
#
# *Five major factors that contributed to the success of an e-commerce store have been identified as: service quality, system quality, information quality, trust and net benefit. The research furthermore investigated the factors that influence the online customers repeat purchase intention. The combination of both utilitarian value and hedonistic values are needed to affect the repeat purchase intention (loyalty) positively.*
# The data is collected from the Indian online shoppers. Results indicate the e-retail success factors, which are very much critical for cust them by extracting in separate excel sheet. The number of column(s) is more than 47. Read the column header carefully.

# %%
import pandas as pd 
import numpy as np 

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings 
warnings.filterwarnings('ignore')

# %%
df= pd.read_excel("F:\Priti\data trained\Customer_retention_dataset\customer_retention_dataset.xlsx", sheet_name=1)
df1= pd.read_excel("F:\Priti\data trained\Customer_retention_dataset\customer_retention_dataset.xlsx", sheet_name=0)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Exploration

# %%
df.head()
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      0                    3
# 1                      1                    2
# 2                      1                    2
# 3                      0                    2
# 4                      1                    2
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                           5
# 1                                           5
# 2                                           4
# 3                                           4
# 4                                           3
#
#    6 How many times you have made an online purchase in the past 1 year?  \
# 0                                                  4
# 1                                                  5
# 2                                                  5
# 3                                                  1
# 4                                                  2
#
#    7 How do you access the internet while shopping on-line?  \
# 0                                                  4
# 1                                                  2
# 2                                                  3
# 3                                                  3
# 4                                                  2
#
#    8 Which device do you use to access the online shopping?  \
# 0                                                  3
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    9 What is the screen size of your mobile device?\t\t\t\t\t\t                                          \
# 0                                                  5
# 1                                                  2
# 2                                                  4
# 3                                                  4
# 4                                                  2
#
#    10 What is the operating system (OS) of your device?\t\t\t\t                                            \
# 0                                                  1
# 1                                                  3
# 2                                                  2
# 3                                                  3
# 4                                                  3
#
#    11 What browser do you run on your device to access the website?\t\t\t                                                            \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  2
# 4                                                  2
#
#    12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                     \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  3
#
#    13 After first visit, how do you reach the online retail store?\t\t\t\t                                                     \
# 0                                                  1
# 1                                                  4
# 2                                                  4
# 3                                                  1
# 4                                                  4
#
#    14 How much time do you explore the e- retail store before making a purchase decision?                                                                     \
# 0                                                  3
# 1                                                  5
# 2                                                  4
# 3                                                  3
# 4                                                  5
#
#    15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                                 \
# 0                                                  4
# 1                                                  1
# 2                                                  4
# 3                                                  1
# 4                                                  1
#
#    16 How 4 do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                     \
# 0                                                  3
# 1                                                  5
# 2                                                  3
# 3                                                  1
# 4                                                  4
#
#    17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                         \
# 0                                                  3
# 1                                                  5
# 2                                                  5
# 3                                                  2
# 4                                                  2
#
#    18 The content on the website must be easy to read and understand  \
# 0                                                  4
# 1                                                  5
# 2                                                  5
# 3                                                  4
# 4                                                  5
#
#    19 Information on similar product to the one highlighted  is important for product comparison  \
# 0                                                  3
# 1                                                  5
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    20 Complete information on listed seller and product being offered is important for purchase decision.  \
# 0                                                  3
# 1                                                  5
# 2                                                  4
# 3                                                  3
# 4                                                  3
#
#    21 All relevant information on listed products must be stated clearly  \
# 0                                                  4
# 1                                                  5
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    22 Ease of navigation in website  23 Loading and processing speed  \
# 0                                 4                                1
# 1                                 5                                5
# 2                                 4                                4
# 3                                 5                                4
# 4                                 4                                5
#
#    24 User friendly Interface of the website  25 Convenient Payment methods  \
# 0                                          2                              2
# 1                                          5                              5
# 2                                          5                              5
# 3                                          5                              5
# 4                                          5                              5
#
#    26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time  \
# 0                                                  2
# 1                                                  5
# 2                                                  5
# 3                                                  4
# 4                                                  4
#
#    27 Empathy (readiness to assist with queries) towards the customers  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    28 Being able to guarantee the privacy of the customer  \
# 0                                                  4
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  4
#
#    29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)  \
# 0                                                  4
# 1                                                  5
# 2                                                  5
# 3                                                  4
# 4                                                  5
#
#    30 Online shopping gives monetary benefit and discounts  \
# 0                                                  3
# 1                                                  5
# 2                                                  5
# 3                                                  4
# 4                                                  5
#
#    31 Enjoyment is derived from shopping online  \
# 0                                             1
# 1                                             5
# 2                                             5
# 3                                             3
# 4                                             5
#
#    32 Shopping online is convenient and flexible  \
# 0                                              2
# 1                                              5
# 2                                              5
# 3                                              3
# 4                                              5
#
#    33 Return and replacement policy of the e-tailer is important for purchase decision  \
# 0                                                  2
# 1                                                  5
# 2                                                  5
# 3                                                  4
# 4                                                  5
#
#    34 Gaining access to loyalty programs is a benefit of shopping online  \
# 0                                                  4
# 1                                                  5
# 2                                                  5
# 3                                                  3
# 4                                                  2
#
#    35 Displaying quality Information on the website improves satisfaction of customers  \
# 0                                                  3
# 1                                                  5
# 2                                                  5
# 3                                                  3
# 4                                                  4
#
#    36 User derive satisfaction while shopping on a good quality website or application  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  4
# 4                                                  5
#
#    37 Net Benefit derived from shopping online can lead to users satisfaction  \
# 0                                                  4
# 1                                                  5
# 2                                                  5
# 3                                                  3
# 4                                                  5
#
#    38 User satisfaction cannot exist without trust  \
# 0                                                5
# 1                                                5
# 2                                                4
# 3                                                4
# 4                                                5
#
#    39 Offering a wide variety of listed product in several category  \
# 0                                                  3
# 1                                                  5
# 2                                                  5
# 3                                                  4
# 4                                                  4
#
#    40 Provision of complete and relevant product information  \
# 0                                                  3
# 1                                                  5
# 2                                                  5
# 3                                                  4
# 4                                                  4
#
#    41 Monetary savings  42 The Convenience of patronizing the online retailer  \
# 0                    2                                                  3
# 1                    5                                                  3
# 2                    5                                                  4
# 3                    5                                                  4
# 4                    5                                                  4
#
#    43 Shopping on the website gives you the sense of adventure  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    44 Shopping on your preferred e-tailer enhances your social status  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  5
# 4                                                  1
#
#    45 You feel gratification shopping on your favorite e-tailer  \
# 0                                                  5
# 1                                                  5
# 2                                                  3
# 3                                                  4
# 4                                                  5
#
#    46 Shopping on the website helps you fulfill certain roles  \
# 0                                                  4
# 1                                                  5
# 2                                                  3
# 3                                                  3
# 4                                                  1
#
#    47 Getting value for money spent  \
# 0                                 5
# 1                                 5
# 2                                 4
# 3                                 4
# 4                                 5
#
#   From the following, tick any (or all) of the online retailers you have shopped from;                                                                             \
# 0                               Amazon.in, Paytm.com
# 1  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 2                   Amazon.in, Paytm.com, Myntra.com
# 3  Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# 4  Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
#
#                   Easy to use website or application  \
# 0                                          Paytm.com
# 1  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 2                   Amazon.in, Paytm.com, Myntra.com
# 3  Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# 4  Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
#
#                     Visual appealing web-page layout  \
# 0                                       Flipkart.com
# 1                              Amazon.in, Myntra.com
# 2                   Amazon.in, Paytm.com, Myntra.com
# 3  Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# 4                                         Myntra.com
#
#   Wild variety of product on offer  \
# 0                     Flipkart.com
# 1         Flipkart.com, Myntra.com
# 2            Amazon.in, Myntra.com
# 3          Amazon.in, Flipkart.com
# 4                       Myntra.com
#
#   Complete, relevant description information of products  \
# 0                                       Snapdeal.com
# 1                Amazon.in, Flipkart.com, Myntra.com
# 2                   Amazon.in, Paytm.com, Myntra.com
# 3                            Amazon.in, Flipkart.com
# 4  Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
#
#   Fast loading website speed of website and application  \
# 0                                       Snapdeal.com
# 1                Amazon.in, Flipkart.com, Myntra.com
# 2                               Amazon.in, Paytm.com
# 3              Amazon.in, Flipkart.com, Snapdeal.com
# 4                                          Amazon.in
#
#   Reliability of the website or application  \
# 0                                 Paytm.com
# 1                                Myntra.com
# 2          Amazon.in, Paytm.com, Myntra.com
# 3        Amazon.in, Flipkart.com, Paytm.com
# 4          Amazon.in, Paytm.com, Myntra.com
#
#                       Quickness to complete purchase  \
# 0                                          Paytm.com
# 1               Amazon.com, Flipkart.com, Myntra.com
# 2                  Amazon.com, Paytm.com, Myntra.com
# 3                Amazon.com, Flipkart.com, Paytm.com
# 4  Amazon.com, Flipkart.com, Paytm.com, Myntra.co...
#
#              Availability of several payment options  \
# 0                                          Patym.com
# 1                Amazon.in, Flipkart.com, Myntra.com
# 2                              Patym.com, Myntra.com
# 3                Amazon.in, Flipkart.com, Myntra.com
# 4  Amazon.in, Flipkart.com, Patym.com, Myntra.com...
#
#                   Speedy order delivery     Privacy of customers’ information  \
# 0                              Amazon.in                            Amazon.in
# 1                Amazon.in, Flipkart.com                           Myntra.com
# 2                              Amazon.in                            Amazon.in
# 3  Amazon.in, Flipkart.com, Snapdeal.com  Amazon.in, Flipkart.com, Myntra.com
# 4                              Amazon.in                 Amazon.in, Paytm.com
#
#   Security of customer financial information  \
# 0                                  Amazon.in
# 1                                 Myntra.com
# 2           Amazon.in, Paytm.com, Myntra.com
# 3      Amazon.in, Flipkart.com, Snapdeal.com
# 4                                  Paytm.com
#
#                Perceived Trustworthiness  \
# 0                           Flipkart.com
# 1                             Myntra.com
# 2                  Amazon.in, Myntra.com
# 3  Amazon.in, Flipkart.com, Snapdeal.com
# 4                  Amazon.in, Myntra.com
#
#   Presence of online assistance through multi-channel  \
# 0                                          Paytm.com
# 1                Amazon.in, Flipkart.com, Myntra.com
# 2                                         Myntra.com
# 3      Amazon.in, Flipkart.com, Myntra.com, Snapdeal
# 4                              Amazon.in, Myntra.com
#
#   Longer time to get logged in (promotion, sales period)  \
# 0                                          Amazon.in
# 1                            Amazon.in, Flipkart.com
# 2                                         Myntra.com
# 3                                       Snapdeal.com
# 4                            Flipkart.com, Paytm.com
#
#   Longer time in displaying graphics and photos (promotion, sales period)  \
# 0                                          Amazon.in
# 1                                         Myntra.com
# 2                                         Myntra.com
# 3                           Myntra.com, Snapdeal.com
# 4                                          Paytm.com
#
#   Late declaration of price (promotion, sales period)  \
# 0                                       Flipkart.com
# 1                                       snapdeal.com
# 2                                         Myntra.com
# 3                                         Myntra.com
# 4                                          Paytm.com
#
#   Longer page loading time (promotion, sales period)  \
# 0                                       Flipkart.com
# 1                                       Snapdeal.com
# 2                                         Myntra.com
# 3                                          Paytm.com
# 4                                          Paytm.com
#
#   Limited mode of payment on most products (promotion, sales period)  \
# 0                                          Amazon.in
# 1                                       Snapdeal.com
# 2                                          Amazon.in
# 3                                          Paytm.com
# 4                                       Snapdeal.com
#
#   Longer delivery period Change in website/Application design  \
# 0              Paytm.com                         Flipkart.com
# 1           Snapdeal.com                            Amazon.in
# 2              Paytm.com                            Paytm.com
# 3              Paytm.com              Amazon.in, Flipkart.com
# 4              Paytm.com                            Amazon.in
#
#   Frequent disruption when moving from one page to another  \
# 0                                          Amazon.in
# 1                                         Myntra.com
# 2                                          Paytm.com
# 3                            Amazon.in, Flipkart.com
# 4                                       Snapdeal.com
#
#     Website is as efficient as before  \
# 0                           Amazon.in
# 1             Amazon.in, Flipkart.com
# 2                           Amazon.in
# 3  Amazon.in, Flipkart.com, Paytm.com
# 4                           Paytm.com
#
#   Which of the Indian online retailer would you recommend to a friend?
# 0                                       Flipkart.com
# 1                              Amazon.in, Myntra.com
# 2                   Amazon.in, Paytm.com, Myntra.com
# 3                            Amazon.in, Flipkart.com
# 4                              Amazon.in, Myntra.com

# %%
df.tail(3)
# Out:
#      1Gender of respondent  2 How old are you?   \
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 266                            Bangalore
# 267                                 Solan
# 268                             Ghaziabad
#
#      4 What is the Pin Code of where you shop online from?  \
# 266                                             560010
# 267                                             173229
# 268                                             201009
#
#      5 Since How Long You are Shopping Online ?  \
# 266                                           3
# 267                                           3
# 268                                           3
#
#      6 How many times you have made an online purchase in the past 1 year?  \
# 266                                                  1
# 267                                                  1
# 268                                                  4
#
#      7 How do you access the internet while shopping on-line?  \
# 266                                                  3
# 267                                                  2
# 268                                                  3
#
#      8 Which device do you use to access the online shopping?  \
# 266                                                  2
# 267                                                  1
# 268                                                  1
#
#      9 What is the screen size of your mobile device?\t\t\t\t\t\t                                          \
# 266                                                  5
# 267                                                  4
# 268                                                  4
#
#      10 What is the operating system (OS) of your device?\t\t\t\t                                            \
# 266                                                  1
# 267                                                  2
# 268                                                  2
#
#      11 What browser do you run on your device to access the website?\t\t\t                                                            \
# 266                                                  1
# 267                                                  1
# 268                                                  1
#
#      12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                     \
# 266                                                  1
# 267                                                  1
# 268                                                  1
#
#      13 After first visit, how do you reach the online retail store?\t\t\t\t                                                     \
# 266                                                  1
# 267                                                  3
# 268                                                  4
#
#      14 How much time do you explore the e- retail store before making a purchase decision?                                                                     \
# 266                                                  5
# 267                                                  2
# 268                                                  4
#
#      15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                                 \
# 266                                                  1
# 267                                                  2
# 268                                                  2
#
#      16 How 4 do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                     \
# 266                                                  3
# 267                                                  3
# 268                                                  1
#
#      17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                         \
# 266                                                  2
# 267                                                  4
# 268                                                  5
#
#      18 The content on the website must be easy to read and understand  \
# 266                                                  5
# 267                                                  5
# 268                                                  5
#
#      19 Information on similar product to the one highlighted  is important for product comparison  \
# 266                                                  5
# 267                                                  4
# 268                                                  5
#
#      20 Complete information on listed seller and product being offered is important for purchase decision.  \
# 266                                                  4
# 267                                                  5
# 268                                                  5
#
#      21 All relevant information on listed products must be stated clearly  \
# 266                                                  4
# 267                                                  4
# 268                                                  5
#
#      22 Ease of navigation in website  23 Loading and processing speed  \
# 266                                 5                                4
# 267                                 4                                4
# 268                                 5                                5
#
#      24 User friendly Interface of the website  25 Convenient Payment methods  \
# 266                                          4                              5
# 267                                          5                              5
# 268                                          5                              5
#
#      26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time  \
# 266                                                  4
# 267                                                  5
# 268                                                  5
#
#      27 Empathy (readiness to assist with queries) towards the customers  \
# 266                                                  3
# 267                                                  5
# 268                                                  5
#
#      28 Being able to guarantee the privacy of the customer  \
# 266                                                  3
# 267                                                  5
# 268                                                  5
#
#      29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)  \
# 266                                                  4
# 267                                                  5
# 268                                                  5
#
#      30 Online shopping gives monetary benefit and discounts  \
# 266                                                  4
# 267                                                  5
# 268                                                  5
#
#      31 Enjoyment is derived from shopping online  \
# 266                                             3
# 267                                             4
# 268                                             5
#
#      32 Shopping online is convenient and flexible  \
# 266                                              4
# 267                                              5
# 268                                              5
#
#      33 Return and replacement policy of the e-tailer is important for purchase decision  \
# 266                                                  5
# 267                                                  4
# 268                                                  5
#
#      34 Gaining access to loyalty programs is a benefit of shopping online  \
# 266                                                  3
# 267                                                  4
# 268                                                  5
#
#      35 Displaying quality Information on the website improves satisfaction of customers  \
# 266                                                  4
# 267                                                  5
# 268                                                  4
#
#      36 User derive satisfaction while shopping on a good quality website or application  \
# 266                                                  4
# 267                                                  5
# 268                                                  5
#
#      37 Net Benefit derived from shopping online can lead to users satisfaction  \
# 266                                                  4
# 267                                                  5
# 268                                                  5
#
#      38 User satisfaction cannot exist without trust  \
# 266                                                4
# 267                                                5
# 268                                                5
#
#      39 Offering a wide variety of listed product in several category  \
# 266                                                  3
# 267                                                  5
# 268                                                  5
#
#      40 Provision of complete and relevant product information  \
# 266                                                  5
# 267                                                  4
# 268                                                  5
#
#      41 Monetary savings  \
# 266                    4
# 267                    4
# 268                    5
#
#      42 The Convenience of patronizing the online retailer  \
# 266                                                  4
# 267                                                  4
# 268                                                  5
#
#      43 Shopping on the website gives you the sense of adventure  \
# 266                                                  2
# 267                                                  4
# 268                                                  5
#
#      44 Shopping on your preferred e-tailer enhances your social status  \
# 266                                                  3
# 267                                                  3
# 268                                                  5
#
#      45 You feel gratification shopping on your favorite e-tailer  \
# 266                                                  4
# 267                                                  3
# 268                                                  5
#
#      46 Shopping on the website helps you fulfill certain roles  \
# 266                                                  4
# 267                                                  4
# 268                                                  5
#
#      47 Getting value for money spent  \
# 266                                 4
# 267                                 3
# 268                                 5
#
#     From the following, tick any (or all) of the online retailers you have shopped from;                                                                             \
# 266              Amazon.in, Flipkart.com, Snapdeal.com
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#                     Easy to use website or application  \
# 266                                          Amazon.in
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#                       Visual appealing web-page layout  \
# 266                                          Amazon.in
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#                       Wild variety of product on offer  \
# 266                                          Amazon.in
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#     Complete, relevant description information of products  \
# 266                                          Amazon.in
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#     Fast loading website speed of website and application  \
# 266                                          Amazon.in
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#              Reliability of the website or application  \
# 266                                          Amazon.in
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#          Quickness to complete purchase  \
# 266                          Amazon.com
# 267  Flipkart.com, Myntra.com, Snapdeal
# 268                          Amazon.com
#
#     Availability of several payment options  \
# 266                 Amazon.in, Flipkart.com
# 267  Flipkart.com, Myntra.com, Snapdeal.com
# 268                               Amazon.in
#
#                      Speedy order delivery   \
# 266                               Amazon.in
# 267  Flipkart.com, Myntra.com, Snapdeal.com
# 268                               Amazon.in
#
#                      Privacy of customers’ information  \
# 266                                          Amazon.in
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#             Security of customer financial information  \
# 266                                          Amazon.in
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#                              Perceived Trustworthiness  \
# 266                                          Amazon.in
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#     Presence of online assistance through multi-channel  \
# 266                                          Amazon.in
# 267      Amazon.in, Flipkart.com, Myntra.com, Snapdeal
# 268                                          Amazon.in
#
#     Longer time to get logged in (promotion, sales period)  \
# 266                                          Amazon.in
# 267                                          Amazon.in
# 268                                          Amazon.in
#
#     Longer time in displaying graphics and photos (promotion, sales period)  \
# 266                                       Snapdeal.com
# 267                Amazon.in, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#     Late declaration of price (promotion, sales period)  \
# 266                                          Amazon.in
# 267                                          Amazon.in
# 268                                          Amazon.in
#
#     Longer page loading time (promotion, sales period)  \
# 266                                       Snapdeal.com
# 267                            Amazon.in, Snapdeal.com
# 268                                          Amazon.in
#
#     Limited mode of payment on most products (promotion, sales period)  \
# 266                                       Snapdeal.com
# 267                                          Amazon.in
# 268                                          Amazon.in
#
#     Longer delivery period Change in website/Application design  \
# 266           Snapdeal.com                         Snapdeal.com
# 267              Amazon.in                            Amazon.in
# 268              Amazon.in                            Amazon.in
#
#     Frequent disruption when moving from one page to another  \
# 266                                       Snapdeal.com
# 267                           Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#     Website is as efficient as before  \
# 266                         Amazon.in
# 267          Myntra.com, Snapdeal.com
# 268                         Amazon.in
#
#     Which of the Indian online retailer would you recommend to a friend?
# 266                                          Amazon.in
# 267                                          Amazon.in
# 268                                          Amazon.in

# %%
df.sample(5)
# Out:
#      1Gender of respondent  2 How old are you?   \
# 146                      1                    5
# 241                      1                    5
# 164                      1                    3
# 39                       1                    2
# 47                       0                    1
#
#     3 Which city do you shop online from?  \
# 146                              Gurgaon
# 241                              Gurgaon
# 164                         Greater Noida
# 39                                Karnal
# 47                                  Delhi
#
#      4 What is the Pin Code of where you shop online from?  \
# 146                                             122018
# 241                                             122009
# 164                                             201310
# 39                                              132036
# 47                                              110011
#
#      5 Since How Long You are Shopping Online ?  \
# 146                                           3
# 241                                           1
# 164                                           5
# 39                                            3
# 47                                            5
#
#      6 How many times you have made an online purchase in the past 1 year?  \
# 146                                                  1
# 241                                                  1
# 164                                                  5
# 39                                                   4
# 47                                                   1
#
#      7 How do you access the internet while shopping on-line?  \
# 146                                                  2
# 241                                                  2
# 164                                                  3
# 39                                                   5
# 47                                                   5
#
#      8 Which device do you use to access the online shopping?  \
# 146                                                  2
# 241                                                  1
# 164                                                  1
# 39                                                   1
# 47                                                   1
#
#      9 What is the screen size of your mobile device?\t\t\t\t\t\t                                          \
# 146                                                  5
# 241                                                  4
# 164                                                  4
# 39                                                   4
# 47                                                   4
#
#      10 What is the operating system (OS) of your device?\t\t\t\t                                            \
# 146                                                  1
# 241                                                  3
# 164                                                  3
# 39                                                   2
# 47                                                   3
#
#      11 What browser do you run on your device to access the website?\t\t\t                                                            \
# 146                                                  1
# 241                                                  1
# 164                                                  2
# 39                                                   1
# 47                                                   2
#
#      12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                     \
# 146                                                  1
# 241                                                  1
# 164                                                  1
# 39                                                   1
# 47                                                   1
#
#      13 After first visit, how do you reach the online retail store?\t\t\t\t                                                     \
# 146                                                  3
# 241                                                  1
# 164                                                  1
# 39                                                   3
# 47                                                   1
#
#      14 How much time do you explore the e- retail store before making a purchase decision?                                                                     \
# 146                                                  5
# 241                                                  4
# 164                                                  3
# 39                                                   2
# 47                                                   3
#
#      15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                                 \
# 146                                                  1
# 241                                                  2
# 164                                                  1
# 39                                                   2
# 47                                                   1
#
#      16 How 4 do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                     \
# 146                                                  3
# 241                                                  4
# 164                                                  1
# 39                                                   3
# 47                                                   1
#
#      17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                         \
# 146                                                  2
# 241                                                  2
# 164                                                  2
# 39                                                   4
# 47                                                   2
#
#      18 The content on the website must be easy to read and understand  \
# 146                                                  5
# 241                                                  5
# 164                                                  4
# 39                                                   5
# 47                                                   4
#
#      19 Information on similar product to the one highlighted  is important for product comparison  \
# 146                                                  5
# 241                                                  4
# 164                                                  4
# 39                                                   4
# 47                                                   4
#
#      20 Complete information on listed seller and product being offered is important for purchase decision.  \
# 146                                                  5
# 241                                                  5
# 164                                                  3
# 39                                                   5
# 47                                                   3
#
#      21 All relevant information on listed products must be stated clearly  \
# 146                                                  5
# 241                                                  5
# 164                                                  4
# 39                                                   4
# 47                                                   4
#
#      22 Ease of navigation in website  23 Loading and processing speed  \
# 146                                 5                                5
# 241                                 4                                4
# 164                                 5                                4
# 39                                  4                                4
# 47                                  5                                4
#
#      24 User friendly Interface of the website  25 Convenient Payment methods  \
# 146                                          5                              5
# 241                                          5                              5
# 164                                          5                              5
# 39                                           5                              5
# 47                                           5                              5
#
#      26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time  \
# 146                                                  5
# 241                                                  3
# 164                                                  4
# 39                                                   5
# 47                                                   4
#
#      27 Empathy (readiness to assist with queries) towards the customers  \
# 146                                                  5
# 241                                                  4
# 164                                                  5
# 39                                                   5
# 47                                                   5
#
#      28 Being able to guarantee the privacy of the customer  \
# 146                                                  5
# 241                                                  4
# 164                                                  5
# 39                                                   5
# 47                                                   5
#
#      29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)  \
# 146                                                  3
# 241                                                  4
# 164                                                  4
# 39                                                   5
# 47                                                   4
#
#      30 Online shopping gives monetary benefit and discounts  \
# 146                                                  4
# 241                                                  4
# 164                                                  4
# 39                                                   5
# 47                                                   4
#
#      31 Enjoyment is derived from shopping online  \
# 146                                             4
# 241                                             3
# 164                                             3
# 39                                              4
# 47                                              3
#
#      32 Shopping online is convenient and flexible  \
# 146                                              4
# 241                                              4
# 164                                              3
# 39                                               5
# 47                                               3
#
#      33 Return and replacement policy of the e-tailer is important for purchase decision  \
# 146                                                  5
# 241                                                  4
# 164                                                  4
# 39                                                   4
# 47                                                   4
#
#      34 Gaining access to loyalty programs is a benefit of shopping online  \
# 146                                                  5
# 241                                                  3
# 164                                                  3
# 39                                                   4
# 47                                                   3
#
#      35 Displaying quality Information on the website improves satisfaction of customers  \
# 146                                                  5
# 241                                                  4
# 164                                                  3
# 39                                                   5
# 47                                                   3
#
#      36 User derive satisfaction while shopping on a good quality website or application  \
# 146                                                  5
# 241                                                  4
# 164                                                  4
# 39                                                   5
# 47                                                   4
#
#      37 Net Benefit derived from shopping online can lead to users satisfaction  \
# 146                                                  5
# 241                                                  3
# 164                                                  3
# 39                                                   5
# 47                                                   3
#
#      38 User satisfaction cannot exist without trust  \
# 146                                                5
# 241                                                4
# 164                                                4
# 39                                                 5
# 47                                                 4
#
#      39 Offering a wide variety of listed product in several category  \
# 146                                                  5
# 241                                                  3
# 164                                                  4
# 39                                                   5
# 47                                                   4
#
#      40 Provision of complete and relevant product information  \
# 146                                                  5
# 241                                                  4
# 164                                                  4
# 39                                                   4
# 47                                                   4
#
#      41 Monetary savings  \
# 146                    3
# 241                    5
# 164                    5
# 39                     4
# 47                     5
#
#      42 The Convenience of patronizing the online retailer  \
# 146                                                  4
# 241                                                  3
# 164                                                  4
# 39                                                   4
# 47                                                   4
#
#      43 Shopping on the website gives you the sense of adventure  \
# 146                                                  2
# 241                                                  3
# 164                                                  4
# 39                                                   4
# 47                                                   4
#
#      44 Shopping on your preferred e-tailer enhances your social status  \
# 146                                                  3
# 241                                                  2
# 164                                                  5
# 39                                                   3
# 47                                                   5
#
#      45 You feel gratification shopping on your favorite e-tailer  \
# 146                                                  3
# 241                                                  3
# 164                                                  4
# 39                                                   3
# 47                                                   4
#
#      46 Shopping on the website helps you fulfill certain roles  \
# 146                                                  2
# 241                                                  2
# 164                                                  3
# 39                                                   4
# 47                                                   3
#
#      47 Getting value for money spent  \
# 146                                 4
# 241                                 4
# 164                                 4
# 39                                  3
# 47                                  4
#
#     From the following, tick any (or all) of the online retailers you have shopped from;                                                                             \
# 146  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 241   Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com
# 164  Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# 39   Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 47   Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
#
#                     Easy to use website or application  \
# 146  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 241                               Amazon.in, Paytm.com
# 164  Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# 39   Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 47   Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
#
#                       Visual appealing web-page layout  \
# 146                           Flipkart.com, Myntra.com
# 241                            Amazon.in, Flipkart.com
# 164  Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# 39   Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 47   Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
#
#                       Wild variety of product on offer  \
# 146                            Amazon.in, Flipkart.com
# 241                            Amazon.in, Flipkart.com
# 164                            Amazon.in, Flipkart.com
# 39   Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 47                             Amazon.in, Flipkart.com
#
#     Complete, relevant description information of products  \
# 146                            Amazon.in, Flipkart.com
# 241              Amazon.in, Flipkart.com, Snapdeal.com
# 164                            Amazon.in, Flipkart.com
# 39   Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 47                             Amazon.in, Flipkart.com
#
#     Fast loading website speed of website and application  \
# 146                Amazon.in, Flipkart.com, Myntra.com
# 241                 Amazon.in, Flipkart.com, Paytm.com
# 164              Amazon.in, Flipkart.com, Snapdeal.com
# 39   Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 47               Amazon.in, Flipkart.com, Snapdeal.com
#
#              Reliability of the website or application  \
# 146                            Amazon.in, Flipkart.com
# 241              Amazon.in, Flipkart.com, Snapdeal.com
# 164                 Amazon.in, Flipkart.com, Paytm.com
# 39   Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 47                  Amazon.in, Flipkart.com, Paytm.com
#
#            Quickness to complete purchase  \
# 146  Amazon.com, Flipkart.com, Myntra.com
# 241              Amazon.com, Flipkart.com
# 164   Amazon.com, Flipkart.com, Paytm.com
# 39     Flipkart.com, Myntra.com, Snapdeal
# 47    Amazon.com, Flipkart.com, Paytm.com
#
#     Availability of several payment options  \
# 146                 Amazon.in, Flipkart.com
# 241   Amazon.in, Flipkart.com, Snapdeal.com
# 164     Amazon.in, Flipkart.com, Myntra.com
# 39   Flipkart.com, Myntra.com, Snapdeal.com
# 47      Amazon.in, Flipkart.com, Myntra.com
#
#                      Speedy order delivery   \
# 146     Amazon.in, Flipkart.com, Myntra.com
# 241                 Amazon.in, Flipkart.com
# 164   Amazon.in, Flipkart.com, Snapdeal.com
# 39   Flipkart.com, Myntra.com, Snapdeal.com
# 47    Amazon.in, Flipkart.com, Snapdeal.com
#
#                      Privacy of customers’ information  \
# 146                                          Amazon.in
# 241              Amazon.in, Flipkart.com, Snapdeal.com
# 164                Amazon.in, Flipkart.com, Myntra.com
# 39   Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 47                 Amazon.in, Flipkart.com, Myntra.com
#
#             Security of customer financial information  \
# 146                                          Amazon.in
# 241  Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# 164              Amazon.in, Flipkart.com, Snapdeal.com
# 39   Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 47               Amazon.in, Flipkart.com, Snapdeal.com
#
#                              Perceived Trustworthiness  \
# 146                                          Amazon.in
# 241                            Amazon.in, Flipkart.com
# 164              Amazon.in, Flipkart.com, Snapdeal.com
# 39   Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 47               Amazon.in, Flipkart.com, Snapdeal.com
#
#     Presence of online assistance through multi-channel  \
# 146                            Amazon.in, Flipkart.com
# 241                                Amazon.in, Snapdeal
# 164      Amazon.in, Flipkart.com, Myntra.com, Snapdeal
# 39       Amazon.in, Flipkart.com, Myntra.com, Snapdeal
# 47       Amazon.in, Flipkart.com, Myntra.com, Snapdeal
#
#     Longer time to get logged in (promotion, sales period)  \
# 146                                         Myntra.com
# 241              Amazon.in, Flipkart.com, Snapdeal.com
# 164                                       Snapdeal.com
# 39                                           Amazon.in
# 47                                        Snapdeal.com
#
#     Longer time in displaying graphics and photos (promotion, sales period)  \
# 146                                       Snapdeal.com
# 241                            Amazon.in, Flipkart.com
# 164                           Myntra.com, Snapdeal.com
# 39                 Amazon.in, Myntra.com, Snapdeal.com
# 47                            Myntra.com, Snapdeal.com
#
#     Late declaration of price (promotion, sales period)  \
# 146                                       snapdeal.com
# 241                            Paytm.com, snapdeal.com
# 164                                         Myntra.com
# 39                                           Amazon.in
# 47                                          Myntra.com
#
#     Longer page loading time (promotion, sales period)  \
# 146                            Paytm.com, Snapdeal.com
# 241                   Amazon.in, Paytm.com, Myntra.com
# 164                                          Paytm.com
# 39                             Amazon.in, Snapdeal.com
# 47                                           Paytm.com
#
#     Limited mode of payment on most products (promotion, sales period)  \
# 146                            Paytm.com, Snapdeal.com
# 241                           Myntra.com, Snapdeal.com
# 164                                          Paytm.com
# 39                                           Amazon.in
# 47                                           Paytm.com
#
#       Longer delivery period Change in website/Application design  \
# 146  Paytm.com, Snapdeal.com              Amazon.in, Flipkart.com
# 241               Myntra.com             Flipkart.com, Myntra.com
# 164                Paytm.com              Amazon.in, Flipkart.com
# 39                 Amazon.in                            Amazon.in
# 47                 Paytm.com              Amazon.in, Flipkart.com
#
#     Frequent disruption when moving from one page to another  \
# 146                                       Snapdeal.com
# 241                                         Myntra.com
# 164                            Amazon.in, Flipkart.com
# 39                            Myntra.com, Snapdeal.com
# 47                             Amazon.in, Flipkart.com
#
#       Website is as efficient as before  \
# 146                        Flipkart.com
# 241                Amazon.in, Paytm.com
# 164  Amazon.in, Flipkart.com, Paytm.com
# 39             Myntra.com, Snapdeal.com
# 47   Amazon.in, Flipkart.com, Paytm.com
#
#     Which of the Indian online retailer would you recommend to a friend?
# 146                Amazon.in, Flipkart.com, Myntra.com
# 241                            Amazon.in, Flipkart.com
# 164                            Amazon.in, Flipkart.com
# 39                                           Amazon.in
# 47                             Amazon.in, Flipkart.com

# %%
df.shape
# Out:
# (269, 71)

# %% [raw]
# Data is having 269 rows and 71 columns.
# The header for each columns is a quetion asked to customers as feedback.
# I am going to change the titles to better understand the data.

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
#        '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ',
#        '14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ',
#        '15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ',
#        '16 How 4 do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ',
#        '17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ',
#        '18 The content on the website must be easy to read and understand',
#        '19 Information on similar product to the one highlighted  is important for product comparison',
#        '20 Complete information on listed seller and product being offered is important for purchase decision.',
#        '21 All relevant information on listed products must be stated clearly',
#        '22 Ease of navigation in website', '23 Loading and processing speed',
#        '24 User friendly Interface of the website',
#        '25 Convenient Payment methods',
#        '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time',
#        '27 Empathy (readiness to assist with queries) towards the customers',
#        '28 Being able to guarantee the privacy of the customer',
#        '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)',
#        '30 Online shopping gives monetary benefit and discounts',
#        '31 Enjoyment is derived from shopping online',
#        '32 Shopping online is convenient and flexible',
#        '33 Return and replacement policy of the e-tailer is important for purchase decision',
#        '34 Gaining access to loyalty programs is a benefit of shopping online',
#        '35 Displaying quality Information on the website improves satisfaction of customers',
#        '36 User derive satisfaction while shopping on a good quality website or application',
#        '37 Net Benefit derived from shopping online can lead to users satisfaction',
#        '38 User satisfaction cannot exist without trust',
#        '39 Offering a wide variety of listed product in several category',
#        '40 Provision of complete and relevant product information',
#        '41 Monetary savings',
#        '42 The Convenience of patronizing the online retailer',
#        '43 Shopping on the website gives you the sense of adventure',
#        '44 Shopping on your preferred e-tailer enhances your social status',
#        '45 You feel gratification shopping on your favorite e-tailer',
#        '46 Shopping on the website helps you fulfill certain roles',
#        '47 Getting value for money spent',
#        'From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ',
#        'Easy to use website or application',
#        'Visual appealing web-page layout', 'Wild variety of product on offer',
#        'Complete, relevant description information of products',
#        'Fast loading website speed of website and application',
#        'Reliability of the website or application',
#        'Quickness to complete purchase',
#        'Availability of several payment options', 'Speedy order delivery ',
#        'Privacy of customers’ information',
#        'Security of customer financial information',
#        'Perceived Trustworthiness',
#        'Presence of online assistance through multi-channel',
#        'Longer time to get logged in (promotion, sales period)',
#        'Longer time in displaying graphics and photos (promotion, sales period)',
#        'Late declaration of price (promotion, sales period)',
#        'Longer page loading time (promotion, sales period)',
#        'Limited mode of payment on most products (promotion, sales period)',
#        'Longer delivery period', 'Change in website/Application design',
#        'Frequent disruption when moving from one page to another',
#        'Website is as efficient as before',
#        'Which of the Indian online retailer would you recommend to a friend?'],
#       dtype='object')

# %%
# to change the titles, let's make dictionary
Dict={'1Gender of respondent':'Gender', '2 How old are you? ':'Age',
       '3 Which city do you shop online from?':'City',
       '4 What is the Pin Code of where you shop online from?':'PinCode',
       '5 Since How Long You are Shopping Online ?': 'Years_of_shoping',
       '6 How many times you have made an online purchase in the past 1 year?':'No_Online_purchage_last_Year',
       '7 How do you access the internet while shopping on-line?':'Internet_Access',
       '8 Which device do you use to access the online shopping?':'Device_Used',
       '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ':'Screen_size',
       '10 What is the operating system (OS) of your device?\t\t\t\t                                          ':'Operating_system',
       '11 What browser do you run on your device to access the website?\t\t\t                                                          ':'Browser_Name',
       '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ':'Channel_Used',
       '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ':'Reach_after_first_visit',
       '14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ':'Decision_Time',
       '15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ':'Preferred_Payment_mode',
       '16 How 4 do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ':'Abondon_shoping',
       '17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ':'Abondon_Reason',
       '18 The content on the website must be easy to read and understand':'Website_content_easeness',
       '19 Information on similar product to the one highlighted  is important for product comparison':'Information_for_Comparision',
       '20 Complete information on listed seller and product being offered is important for purchase decision.':'SellerProduct_info',
       '21 All relevant information on listed products must be stated clearly':'Clear_information',
       '22 Ease of navigation in website':'Ease_of_navigation', '23 Loading and processing speed':'Loading_processing_speed',
       '24 User friendly Interface of the website':'UserFriendly_Interface',
       '25 Convenient Payment methods':'Convenient_pay_mode',
       '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time':'Trust',
       '27 Empathy (readiness to assist with queries) towards the customers':'Empathy_to_customer',
       '28 Being able to guarantee the privacy of the customer':'Privacy_of_customers',
       '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)':'Comm_channels_Responsiveness',
       '30 Online shopping gives monetary benefit and discounts':'Monetry_benefits_and_discounts',
       '31 Enjoyment is derived from shopping online':'Enjoyement',
       '32 Shopping online is convenient and flexible':'Convenient_and_Flexible',
       '33 Return and replacement policy of the e-tailer is important for purchase decision':'Retirn_policy',
       '34 Gaining access to loyalty programs is a benefit of shopping online':'Loyality_program',
       '35 Displaying quality Information on the website improves satisfaction of customers':'Quality_info_on_web',
       '36 User derive satisfaction while shopping on a good quality website or application':'Satisfaction_due_to_good_quality_website',
       '37 Net Benefit derived from shopping online can lead to users satisfaction':'Net_benefits',
       '38 User satisfaction cannot exist without trust':'Satisfaction_Trust',
       '39 Offering a wide variety of listed product in several category':'Wide_variety',
       '40 Provision of complete and relevant product information':'Complete_Relevent_info',
       '41 Monetary savings':'Monetary_savings',
       '42 The Convenience of patronizing the online retailer':'Convenience_of_patronizing',
       '43 Shopping on the website gives you the sense of adventure':'Sense_of_advanture',
       '44 Shopping on your preferred e-tailer enhances your social status':'Social_status',
       '45 You feel gratification shopping on your favorite e-tailer':'gratification',
       '46 Shopping on the website helps you fulfill certain roles':'Help_fullfill_roles',
       '47 Getting value for money spent':'Value_of_money',
       'From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ':'Online_retailer',
       'Easy to use website or application':'Easy_use_webapp',
       'Visual appealing web-page layout':'Visual_appealing', 'Wild variety of product on offer':'Wild_variety',
       'Complete, relevant description information of products':'Informtion_of_product',
       'Fast loading website speed of website and application':'Fast_loading_webApp',
       'Reliability of the website or application':'Reliability',
       'Quickness to complete purchase':'Quickness_purpchase',
       'Availability of several payment options':'Payment_option', 'Speedy order delivery ':'Speedy_delivery',
       'Privacy of customers’ information':'Info_Privacy',
       'Security of customer financial information':'Fincial_info_security',
       'Perceived Trustworthiness':'Perceived_Trustworthiness',
       'Presence of online assistance through multi-channel':'Online_assistance',
       'Longer time to get logged in (promotion, sales period)':'Longer_logged_in',
       'Longer time in displaying graphics and photos (promotion, sales period)':'Longer_display_time',
       'Late declaration of price (promotion, sales period)':'Late_price_declaration',
       'Longer page loading time (promotion, sales period)':'Longer_page_loading',
       'Limited mode of payment on most products (promotion, sales period)':'Limited_payment_mode',
       'Longer delivery period':'Long_delivary_period', 'Change in website/Application design':'Change_in_website',
       'Frequent disruption when moving from one page to another':'Frequent_disruption',
       'Website is as efficient as before':'Efficient_website',
       'Which of the Indian online retailer would you recommend to a friend?':'Recommended_retailers'}

# %%
df.rename(columns=Dict, inplace=True)

# %%
df1.rename(columns=Dict, inplace=True)

# %%
df.head()
# Out:
#    Gender  Age           City  PinCode  Years_of_shoping  \
# 0       0    3          Delhi   110009                 5
# 1       1    2          Delhi   110030                 5
# 2       1    2  Greater Noida   201308                 4
# 3       0    2        Karnal    132001                 4
# 4       1    2     Bangalore    530068                 3
#
#    No_Online_purchage_last_Year  Internet_Access  Device_Used  Screen_size  \
# 0                             4                4            3            5
# 1                             5                2            1            2
# 2                             5                3            1            4
# 3                             1                3            1            4
# 4                             2                2            1            2
#
#    Operating_system  Browser_Name  Channel_Used  Reach_after_first_visit  \
# 0                 1             1             1                        1
# 1                 3             1             1                        4
# 2                 2             1             1                        4
# 3                 3             2             1                        1
# 4                 3             2             3                        4
#
#    Decision_Time  Preferred_Payment_mode  Abondon_shoping  Abondon_Reason  \
# 0              3                       4                3               3
# 1              5                       1                5               5
# 2              4                       4                3               5
# 3              3                       1                1               2
# 4              5                       1                4               2
#
#    Website_content_easeness  Information_for_Comparision  SellerProduct_info  \
# 0                         4                            3                   3
# 1                         5                            5                   5
# 2                         5                            4                   4
# 3                         4                            4                   3
# 4                         5                            3                   3
#
#    Clear_information  Ease_of_navigation  Loading_processing_speed  \
# 0                  4                   4                         1
# 1                  5                   5                         5
# 2                  4                   4                         4
# 3                  4                   5                         4
# 4                  4                   4                         5
#
#    UserFriendly_Interface  Convenient_pay_mode  Trust  Empathy_to_customer  \
# 0                       2                    2      2                    5
# 1                       5                    5      5                    5
# 2                       5                    5      5                    5
# 3                       5                    5      4                    5
# 4                       5                    5      4                    5
#
#    Privacy_of_customers  Comm_channels_Responsiveness  \
# 0                     4                             4
# 1                     5                             5
# 2                     5                             5
# 3                     5                             4
# 4                     4                             5
#
#    Monetry_benefits_and_discounts  Enjoyement  Convenient_and_Flexible  \
# 0                               3           1                        2
# 1                               5           5                        5
# 2                               5           5                        5
# 3                               4           3                        3
# 4                               5           5                        5
#
#    Retirn_policy  Loyality_program  Quality_info_on_web  \
# 0              2                 4                    3
# 1              5                 5                    5
# 2              5                 5                    5
# 3              4                 3                    3
# 4              5                 2                    4
#
#    Satisfaction_due_to_good_quality_website  Net_benefits  Satisfaction_Trust  \
# 0                                         5             4                   5
# 1                                         5             5                   5
# 2                                         5             5                   4
# 3                                         4             3                   4
# 4                                         5             5                   5
#
#    Wide_variety  Complete_Relevent_info  Monetary_savings  \
# 0             3                       3                 2
# 1             5                       5                 5
# 2             5                       5                 5
# 3             4                       4                 5
# 4             4                       4                 5
#
#    Convenience_of_patronizing  Sense_of_advanture  Social_status  \
# 0                           3                   4              4
# 1                           3                   3              3
# 2                           4                   4              4
# 3                           4                   4              5
# 4                           4                   3              1
#
#    gratification  Help_fullfill_roles  Value_of_money  \
# 0              5                    4               5
# 1              5                    5               5
# 2              3                    3               4
# 3              4                    3               4
# 4              5                    1               5
#
#                                      Online_retailer  \
# 0                               Amazon.in, Paytm.com
# 1  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 2                   Amazon.in, Paytm.com, Myntra.com
# 3  Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# 4  Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
#
#                                      Easy_use_webapp  \
# 0                                          Paytm.com
# 1  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 2                   Amazon.in, Paytm.com, Myntra.com
# 3  Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# 4  Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
#
#                                     Visual_appealing  \
# 0                                       Flipkart.com
# 1                              Amazon.in, Myntra.com
# 2                   Amazon.in, Paytm.com, Myntra.com
# 3  Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# 4                                         Myntra.com
#
#                Wild_variety  \
# 0              Flipkart.com
# 1  Flipkart.com, Myntra.com
# 2     Amazon.in, Myntra.com
# 3   Amazon.in, Flipkart.com
# 4                Myntra.com
#
#                                Informtion_of_product  \
# 0                                       Snapdeal.com
# 1                Amazon.in, Flipkart.com, Myntra.com
# 2                   Amazon.in, Paytm.com, Myntra.com
# 3                            Amazon.in, Flipkart.com
# 4  Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
#
#                      Fast_loading_webApp                         Reliability  \
# 0                           Snapdeal.com                           Paytm.com
# 1    Amazon.in, Flipkart.com, Myntra.com                          Myntra.com
# 2                   Amazon.in, Paytm.com    Amazon.in, Paytm.com, Myntra.com
# 3  Amazon.in, Flipkart.com, Snapdeal.com  Amazon.in, Flipkart.com, Paytm.com
# 4                              Amazon.in    Amazon.in, Paytm.com, Myntra.com
#
#                                  Quickness_purpchase  \
# 0                                          Paytm.com
# 1               Amazon.com, Flipkart.com, Myntra.com
# 2                  Amazon.com, Paytm.com, Myntra.com
# 3                Amazon.com, Flipkart.com, Paytm.com
# 4  Amazon.com, Flipkart.com, Paytm.com, Myntra.co...
#
#                                       Payment_option  \
# 0                                          Patym.com
# 1                Amazon.in, Flipkart.com, Myntra.com
# 2                              Patym.com, Myntra.com
# 3                Amazon.in, Flipkart.com, Myntra.com
# 4  Amazon.in, Flipkart.com, Patym.com, Myntra.com...
#
#                          Speedy_delivery                         Info_Privacy  \
# 0                              Amazon.in                            Amazon.in
# 1                Amazon.in, Flipkart.com                           Myntra.com
# 2                              Amazon.in                            Amazon.in
# 3  Amazon.in, Flipkart.com, Snapdeal.com  Amazon.in, Flipkart.com, Myntra.com
# 4                              Amazon.in                 Amazon.in, Paytm.com
#
#                    Fincial_info_security  \
# 0                              Amazon.in
# 1                             Myntra.com
# 2       Amazon.in, Paytm.com, Myntra.com
# 3  Amazon.in, Flipkart.com, Snapdeal.com
# 4                              Paytm.com
#
#                Perceived_Trustworthiness  \
# 0                           Flipkart.com
# 1                             Myntra.com
# 2                  Amazon.in, Myntra.com
# 3  Amazon.in, Flipkart.com, Snapdeal.com
# 4                  Amazon.in, Myntra.com
#
#                                Online_assistance         Longer_logged_in  \
# 0                                      Paytm.com                Amazon.in
# 1            Amazon.in, Flipkart.com, Myntra.com  Amazon.in, Flipkart.com
# 2                                     Myntra.com               Myntra.com
# 3  Amazon.in, Flipkart.com, Myntra.com, Snapdeal             Snapdeal.com
# 4                          Amazon.in, Myntra.com  Flipkart.com, Paytm.com
#
#         Longer_display_time Late_price_declaration Longer_page_loading  \
# 0                 Amazon.in           Flipkart.com        Flipkart.com
# 1                Myntra.com           snapdeal.com        Snapdeal.com
# 2                Myntra.com             Myntra.com          Myntra.com
# 3  Myntra.com, Snapdeal.com             Myntra.com           Paytm.com
# 4                 Paytm.com              Paytm.com           Paytm.com
#
#   Limited_payment_mode Long_delivary_period        Change_in_website  \
# 0            Amazon.in            Paytm.com             Flipkart.com
# 1         Snapdeal.com         Snapdeal.com                Amazon.in
# 2            Amazon.in            Paytm.com                Paytm.com
# 3            Paytm.com            Paytm.com  Amazon.in, Flipkart.com
# 4         Snapdeal.com            Paytm.com                Amazon.in
#
#        Frequent_disruption                   Efficient_website  \
# 0                Amazon.in                           Amazon.in
# 1               Myntra.com             Amazon.in, Flipkart.com
# 2                Paytm.com                           Amazon.in
# 3  Amazon.in, Flipkart.com  Amazon.in, Flipkart.com, Paytm.com
# 4             Snapdeal.com                           Paytm.com
#
#               Recommended_retailers
# 0                      Flipkart.com
# 1             Amazon.in, Myntra.com
# 2  Amazon.in, Paytm.com, Myntra.com
# 3           Amazon.in, Flipkart.com
# 4             Amazon.in, Myntra.com

# %%
# to check missing values
df.isnull().sum()
# Out:
# Gender                                      0
# Age                                         0
# City                                        0
# PinCode                                     0
# Years_of_shoping                            0
# No_Online_purchage_last_Year                0
# Internet_Access                             0
# Device_Used                                 0
# Screen_size                                 0
# Operating_system                            0
# Browser_Name                                0
# Channel_Used                                0
# Reach_after_first_visit                     0
# Decision_Time                               0
# Preferred_Payment_mode                      0
# Abondon_shoping                             0
# Abondon_Reason                              0
# Website_content_easeness                    0
# Information_for_Comparision                 0
# SellerProduct_info                          0
# Clear_information                           0
# Ease_of_navigation                          0
# Loading_processing_speed                    0
# UserFriendly_Interface                      0
# Convenient_pay_mode                         0
# Trust                                       0
# Empathy_to_customer                         0
# Privacy_of_customers                        0
# Comm_channels_Responsiveness                0
# Monetry_benefits_and_discounts              0
# Enjoyement                                  0
# Convenient_and_Flexible                     0
# Retirn_policy                               0
# Loyality_program                            0
# Quality_info_on_web                         0
# Satisfaction_due_to_good_quality_website    0
# Net_benefits                                0
# Satisfaction_Trust                          0
# Wide_variety                                0
# Complete_Relevent_info                      0
# Monetary_savings                            0
# Convenience_of_patronizing                  0
# Sense_of_advanture                          0
# Social_status                               0
# gratification                               0
# Help_fullfill_roles                         0
# Value_of_money                              0
# Online_retailer                             0
# Easy_use_webapp                             0
# Visual_appealing                            0
# Wild_variety                                0
# Informtion_of_product                       0
# Fast_loading_webApp                         0
# Reliability                                 0
# Quickness_purpchase                         0
# Payment_option                              0
# Speedy_delivery                             0
# Info_Privacy                                0
# Fincial_info_security                       0
# Perceived_Trustworthiness                   0
# Online_assistance                           0
# Longer_logged_in                            0
# Longer_display_time                         0
# Late_price_declaration                      0
# Longer_page_loading                         0
# Limited_payment_mode                        0
# Long_delivary_period                        0
# Change_in_website                           0
# Frequent_disruption                         0
# Efficient_website                           0
# Recommended_retailers                       0
# dtype: int64

# %% [markdown]
# Dataset have no missing values.

# %% [markdown]
# # EDA and Visualization

# %% [markdown]
# How many shoppers are Male and Female?

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Gender'])
plt.xlabel('Gender', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.title('Gender', fontsize=10)

df1['Gender'].value_counts()/269*100
# Out:
# Female    67.286245
# Male      32.713755
# Name: Gender, dtype: float64

# %% [markdown]
# Most of online shoppers are female.

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Age'])
plt.xlabel('Age', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.title('Age', fontsize=10)

df1['Gender'].value_counts()/269*100
# Out:
# Female    67.286245
# Male      32.713755
# Name: Gender, dtype: float64

# %% [markdown]
# Graph shows maximum online shoppers are from age group 31-40 Years.
# More than 75 percent of online shoppers are lies between 21-50 years old.
# Numbers for less than 20 years and above 51 are less, which indicates thease age group rarely use online shoping.

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['City'])
plt.xlabel('City', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.title('City', fontsize=10)

df1['City'].value_counts()/269*100
# Out:
# Delhi            21.561338
# Greater Noida    15.985130
# Noida            14.869888
# Bangalore        13.754647
# Karnal           10.037175
# Solan             6.691450
# Ghaziabad         6.691450
# Gurgaon           4.460967
# Merrut            3.345725
# Moradabad         1.858736
# Bulandshahr       0.743494
# Name: City, dtype: float64

# %% [markdown]
# From graph we can see Delhi Having Highest Number of customers who shope online.
# Graph also showing that most of the customers are from Delhi, Greater Noida, Noida, Banglore and Karnal.

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Years_of_shoping'])
plt.xlabel('Years_of_shoping', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.title('Years_of_shoping', fontsize=10)

df1['Years_of_shoping'].value_counts()/269*100
# Out:
# Above 4 years       36.431227
# 2-3 years           24.163569
# 3-4 years           17.472119
# Less than 1 year    15.985130
# 1-2 years            5.947955
# Name: Years_of_shoping, dtype: float64

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['No_Online_purchage_last_Year'])
plt.xlabel('No_Online_purchage_last_Year', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.title('No_Online_purchage_last_Year', fontsize=10)

df1['No_Online_purchage_last_Year'].value_counts()/269*100
# Out:
# Less than 10 times    42.379182
# 31-40 times           23.420074
# 41 times and above    17.472119
# 11-20 times           10.780669
# 21-30 times            3.717472
# 42 times and above     2.230483
# Name: No_Online_purchage_last_Year, dtype: float64

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Internet_Access'])
plt.xlabel('Internet_Access', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.title('Internet_Access', fontsize=10)

df1['Internet_Access'].value_counts()/269*100
# Out:
# Mobile Internet    70.260223
# Wi-Fi              28.252788
# Dial-up             1.486989
# Name: Internet_Access, dtype: float64

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Device_Used'])
plt.xlabel('Device_Used', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.title('Device_Used', fontsize=10)

df1['Device_Used'].value_counts()/269*100
# Out:
# Smartphone    52.416357
# Laptop        31.970260
# Desktop       11.152416
# Tablet         4.460967
# Name: Device_Used, dtype: float64

# %% [markdown]
# People are using smartphone the most for online shopping.

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Screen_size'])
plt.xlabel('Screen_size', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.title('Screen_size', fontsize=10)

df1['Screen_size'].value_counts()/269*100
# Out:
# Others        49.814126
# 5.5 inches    36.802974
# 4.7 inches    10.780669
# 5 inches       2.602230
# Name: Screen_size, dtype: float64

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Operating_system'])
plt.xlabel('Operating_system', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.title('Operating_system', fontsize=10)

df1['Operating_system'].value_counts()/269*100
# Out:
# Window/windows Mobile    45.353160
# Android                  31.598513
# IOS/Mac                  23.048327
# Name: Operating_system, dtype: float64

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Browser_Name'])
plt.xlabel('Browser_Name', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.title('Browser_Name', fontsize=10)

df1['Browser_Name'].value_counts()/269*100
# Out:
# Google chrome      80.297398
# Safari             14.869888
# Opera               2.973978
# Mozilla Firefox     1.858736
# Name: Browser_Name, dtype: float64

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Channel_Used'])
plt.xlabel('Channel_Used', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.title('Channel_Used', fontsize=10)

df1['Channel_Used'].value_counts()/269*100
# Out:
# Search Engine        85.501859
# Content Marketing     7.434944
# Display Adverts       7.063197
# Name: Channel_Used, dtype: float64

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Reach_after_first_visit'])
plt.xlabel('Reach_after_first_visit', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.title('Reach_after_first_visit', fontsize=10)

df1['Reach_after_first_visit'].value_counts()/269*100
# Out:
# Search Engine      32.342007
# Via application    31.970260
# Direct URL         26.022305
# E-mail              6.691450
# Social Media        2.973978
# Name: Reach_after_first_visit, dtype: float64

# %% [markdown]
# Search engine and application are used for online shopping.

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Decision_Time'])
plt.xlabel('Decision_Time', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.title('Decision_Time', fontsize=10)

df1['Decision_Time'].value_counts()/269*100
# Out:
# more than 15 mins    45.724907
# 6-10 mins            26.394052
# 11-15 mins           17.100372
# Less than 1 min       5.576208
# 1-5 mins              5.204461
# Name: Decision_Time, dtype: float64

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Preferred_Payment_mode'])
plt.xlabel('Preferred_Payment_mode', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.title('Preferred_Payment_mode', fontsize=10)

df1['Preferred_Payment_mode'].value_counts()/269*100
# Out:
# Credit/Debit cards                    55.018587
# Cash on delivery (CoD)                28.252788
# E-wallets (Paytm, Freecharge etc.)    16.728625
# Name: Preferred_Payment_mode, dtype: float64

# %% [markdown]
# Majority of people are using Credit/debit card for online shopping.

# %%
plt.figure(figsize=(8,7))
sns.countplot(df['Abondon_shoping'])
plt.xlabel('Abondon_shoping', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Abondon_shoping', fontsize=14)
plt.grid()

# %%
plt.figure(figsize=(12,7))
sns.countplot(df1['Abondon_Reason'])
plt.xlabel('Abondon_Reason', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Abondon_Reason', fontsize=14)
plt.grid()

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Website_content_easeness'])
plt.xlabel('Website_content_easeness', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.title('Website_content_easeness', fontsize=10)

df1['Website_content_easeness'].value_counts()/269*100
# Out:
# Strongly agree (5)       60.966543
# Agree (4)                29.739777
# Strongly disagree (1)     6.691450
# Indifferent (3)           2.602230
# Name: Website_content_easeness, dtype: float64

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Information_for_Comparision'])
plt.xlabel('Information_for_Comparision', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.title('Information_for_Comparision', fontsize=10)

df1['Information_for_Comparision'].value_counts()/269*100
# Out:
# Strongly agree (5)    43.122677
# Agree (4)             34.200743
# Indifferent (3)       15.985130
# Dis-agree (2)          6.691450
# Name: Information_for_Comparision, dtype: float64

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['SellerProduct_info'])
plt.xlabel('SellerProduct_info', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.title('SellerProduct_info', fontsize=10)

df1['SellerProduct_info'].value_counts()/269*100
# Out:
# Agree (4)                37.546468
# Strongly agree (5)       32.342007
# Indifferent (3)          19.330855
# Dis-agree (2)             6.691450
# Strongly disagree (1)     4.089219
# Name: SellerProduct_info, dtype: float64

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Clear_information'])
plt.xlabel('Clear_information', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.title('Clear_information', fontsize=10)

df1['Clear_information'].value_counts()/269*100
# Out:
# Agree (4)                49.070632
# Strongly agree (5)       39.776952
# Strongly disagree (1)     6.691450
# Dis-agree (2)             4.460967
# Name: Clear_information, dtype: float64

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Ease_of_navigation'])
plt.xlabel('Ease_of_navigation', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.title('Ease_of_navigation', fontsize=10)

df1['Ease_of_navigation'].value_counts()/269*100
# Out:
# Strongly agree (5)       52.416357
# Agree (4)                39.033457
# Strongly disagree (1)     6.691450
# Dis-agree (2)             1.858736
# Name: Ease_of_navigation, dtype: float64

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Loading_processing_speed'])
plt.xlabel('Loading_processing_speed', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.title('Loading_processing_speed', fontsize=10)

df1['Loading_processing_speed'].value_counts()/269*100
# Out:
# Strongly agree (5)       42.750929
# Agree (4)                41.635688
# Dis-agree (2)             6.691450
# Strongly disagree (1)     4.460967
# Indifferent (3)           4.460967
# Name: Loading_processing_speed, dtype: float64

# %% [markdown]
# Most of shoppers are strogly agree that loading and processing speed is affecting in buying decision.

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['UserFriendly_Interface'])
plt.xlabel('UserFriendly_Interface', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.title('UserFriendly_Interface', fontsize=10)

df1['UserFriendly_Interface'].value_counts()/269*100
# Out:
# Strongly agree (5)       70.260223
# Agree (4)                16.728625
# Strongly disagree (1)     6.691450
# Dis-agree (2)             4.460967
# Indifferent (3)           1.858736
# Name: UserFriendly_Interface, dtype: float64

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Convenient_pay_mode'])
plt.xlabel('Convenient_pay_mode', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.title('Convenient_pay_mode', fontsize=10)

df1['Convenient_pay_mode'].value_counts()/269*100
# Out:
# Strongly agree (5)    59.107807
# Agree (4)             29.739777
# Dis-agree (2)         11.152416
# Name: Convenient_pay_mode, dtype: float64

# %% [markdown]
# Most of the shoppers are strongly agree that having conveniet pay mode affect the Buying decision.

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Trust'])
plt.xlabel('Trust', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.title('Trust', fontsize=10)

df1['Trust'].value_counts()/269*100
# Out:
# Strongly agree (5)    52.416357
# Agree (4)             31.970260
# Disagree (2)          11.152416
# indifferent  (3)       4.460967
# Name: Trust, dtype: float64

# %% [markdown]
# Most of the people have trust for transaction, for making buying decision

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Empathy_to_customer'])
plt.xlabel('Empathy_to_customer', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Empathy_to_customer', fontsize=14)
plt.grid()

# %% [markdown]
# Majority of the shoppers are agree that having empathy to customers, affect the chance of buying

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Privacy_of_customers'])
plt.xlabel('Privacy_of_customers', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Privacy_of_customers', fontsize=14)
plt.grid()

# %% [markdown]
# Graphs showing privicy play important role in making buying descisions, majority of the shoppers are strongly agree.

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Comm_channels_Responsiveness'])
plt.xlabel('Comm_channels_Responsiveness', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Comm_channels_Responsiveness', fontsize=14)
plt.grid()

# %% [markdown]
# Majority of the shoppers are agree that having Responsiveness Communication channels, affect the chance of buying.

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Monetry_benefits_and_discounts'])
plt.xlabel('Monetry_benefits_and_discounts', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Monetry_benefits_and_discounts', fontsize=14)
plt.grid()

# %% [markdown]
# Majority of the shoppers are agree that online shoping gives Monetry Benefits and disconts.

# %%
plt.figure(figsize=(10,7))
sns.countplot(df1['Enjoyement'])
plt.xlabel('Enjoyement', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Enjoyement', fontsize=14)
plt.grid()

# %% [markdown]
# Majority of the shoppers are strongly agree to have enjoyment from online shoping online

# %%
plt.figure(figsize=(10,7))
sns.countplot(df1['Convenient_and_Flexible'])
plt.xlabel('Convenient_and_Flexible', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Convenient_and_Flexible', fontsize=14)
plt.grid()

# %% [markdown]
# Majority of the shoppers are strongly agree that shoping online is Convenient and Flexible.

# %%
plt.figure(figsize=(10,7))
sns.countplot(df1['Retirn_policy'])
plt.xlabel('Retirn_policy', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Retirn_policy', fontsize=14)
plt.grid()

# %% [markdown]
# Majority of the shoppers are strongly agree that Return policy affect the buying decisonm.

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Loyality_program'])
plt.xlabel('Loyality_program', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Loyality_program', fontsize=14)
plt.grid()

# %% [markdown]
# Majority of the shoppers are strongly agree that Gaining access to loyalty programs is a benefit of shopping online.

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Quality_info_on_web'])
plt.xlabel('Quality_info_on_web', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Quality_info_on_web', fontsize=14)
plt.grid()

# %% [markdown]
# Majority of shoppers are strongly agree Displaying quality Information on the website improves satisfaction of customers.

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Satisfaction_due_to_good_quality_website'])
plt.xlabel('Satisfaction_due_to_good_quality_website', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Satisfaction_due_to_good_quality_website', fontsize=14)
plt.grid()

# %% [markdown]
# Majority of the shoppers are strongly agree User derive satisfaction while shopping on a good quality website or application.

# %%
plt.figure(figsize=(10,7))
sns.countplot(df1['Net_benefits'])
plt.xlabel('Net_benefits', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Net_benefits', fontsize=14)
plt.grid()

# %% [markdown]
# Majority of the shoppers are strongly agree that Net Benefit derived from shopping online can lead to users satisfaction.

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Satisfaction_Trust'])
plt.xlabel('Satisfaction_Trust', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Satisfaction_Trust', fontsize=14)
plt.grid()

# %% [markdown]
# Majority of the shoppers strogly agree that User satisfaction cannot exist without trust.

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Wide_variety'])
plt.xlabel('Wide_variety', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Wide_variety', fontsize=14)
plt.grid()

# %% [markdown]
# Majority of the shoppers are agree that online shoping Offering a wide variety of listed product in several category.

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Complete_Relevent_info'])
plt.xlabel('Complete_Relevent_info', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Complete_Relevent_info', fontsize=14)
plt.grid()

# %% [markdown]
# Majority of the shoppers are strongly agree that having complete and relevant product information increase chance of buying .

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Monetary_savings'])
plt.xlabel('Monetary_savings', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Monetary_savings', fontsize=14)
plt.grid()

# %% [markdown]
# Majority of the shoppers strongly agree that online shoping provide monetary savings.

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Convenience_of_patronizing'])
plt.xlabel('Convenience_of_patronizing', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Convenience_of_patronizing', fontsize=14)
plt.grid()

# %% [markdown]
# Majority of the shoppers are agree,There is Convenience of patronizing the online retailer.

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Sense_of_advanture'])
plt.xlabel('Sense_of_advanture', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Sense_of_advanture', fontsize=14)
plt.grid()

# %% [markdown]
# Majority of the shoppers are agree that Shopping on the website gives you the sense of adventure.

# %%
plt.figure(figsize=(10,7))
sns.countplot(df1['Social_status'])
plt.xlabel('Social_status', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Social_status', fontsize=14)
plt.grid()

# %% [markdown]
# Majority of the online shoppers are having Indiffrent views for Shopping on your preferred e-tailer enhances your social status.

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['gratification'])
plt.xlabel('gratification', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('gratification', fontsize=14)
plt.grid()

# %% [markdown]
# Shoppers having Indiffrent view for feel gratification shopping on your favorite e-tailer.

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Help_fullfill_roles'])
plt.xlabel('Help_fullfill_roles', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Help_fullfill_roles', fontsize=14)
plt.grid()

# %%
plt.figure(figsize=(8,7))
sns.countplot(df1['Value_of_money'])
plt.xlabel('Value_of_money', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Value_of_money', fontsize=14)
plt.grid()

# %% [markdown]
# Majority of the shoppers are agree to have value of money.

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Online_retailer'])
plt.xlabel('Online_retailer', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Online_retailer', fontsize=14)
plt.grid()

# %% [markdown]
# Majority of the shoppers are using multiple retailers for shoping online.

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Easy_use_webapp'])
plt.xlabel('Count', fontsize=14)
plt.ylabel('Easy_use_webapp', fontsize=14)
plt.title('Easy_use_webapp', fontsize=14)
plt.grid()

# %% [markdown]
# Majority of website and applications are easy to use.

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Visual_appealing'])
plt.xlabel('Count', fontsize=14)
plt.ylabel('Visual_appealing', fontsize=14)
plt.title('Visual_appealing', fontsize=14)
plt.grid()

# %% [markdown]
# accordig Majority of shoppers Amazon and Flipcart having good visual appealing.

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Wild_variety'])
plt.xlabel('Count', fontsize=14)
plt.ylabel('Wild_variety', fontsize=14)
plt.title('Wild_variety', fontsize=14)
plt.grid()

# %% [markdown]
# Amazon and flipcart are having wild variety of prodcts on offer.

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Informtion_of_product'])
plt.xlabel('Count', fontsize=14)
plt.ylabel('Informtion_of_product', fontsize=14)
plt.title('Informtion_of_product', fontsize=14)
plt.grid()

# %% [markdown]
# Amazon and Flipcart having Complete, relevant description information of products.

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Fast_loading_webApp'])
plt.xlabel('Count', fontsize=14)
plt.ylabel('Fast_loading_webApp', fontsize=14)
plt.title('Fast_loading_webApp', fontsize=14)
plt.grid()

# %% [markdown]
# Amazon, flipcart and Paytm having fastest loading website and application.

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Reliability'])
plt.xlabel('Count', fontsize=14)
plt.ylabel('Reliability', fontsize=14)
plt.title('Reliability', fontsize=14)
plt.grid()

# %% [markdown]
# According to majority of the shopers amazon is more Reliabil website or application.

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Quickness_purpchase'])
plt.xlabel('Count', fontsize=14)
plt.ylabel('Quickness_purpchase', fontsize=14)
plt.title('Quickness_purpchase', fontsize=14)
plt.grid()

# %% [markdown]
# According to majority of the shoppers amazon is having Quickness to complete purchase.

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Payment_option'])
plt.xlabel('Count', fontsize=14)
plt.ylabel('Payment_option', fontsize=14)
plt.title('Payment_option', fontsize=14)
plt.grid()

# %% [markdown]
# Amazon and Flipcart are having Availability of several payment options.

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Speedy_delivery'])
plt.xlabel('Count', fontsize=14)
plt.ylabel('Speedy_delivery', fontsize=14)
plt.title('Speedy_delivery', fontsize=14)
plt.grid()

# %% [markdown]
# Amazon provide Speedy order delivery.

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Info_Privacy'])
plt.xlabel('Count', fontsize=14)
plt.ylabel('Info_Privacy', fontsize=14)
plt.title('Info_Privacy', fontsize=14)
plt.grid()

# %% [markdown]
# Majority of the shoppers recommend Amazon as best retails for provideing mPrivacy of customers’ information.

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Fincial_info_security'])
plt.xlabel('Count', fontsize=14)
plt.ylabel('Fincial_info_security', fontsize=14)
plt.title('Fincial_info_security', fontsize=14)
plt.grid()

# %% [markdown]
# Majority of retails provide Security of customer financial information.

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Perceived_Trustworthiness'])
plt.xlabel('Count', fontsize=14)
plt.ylabel('Perceived_Trustworthiness', fontsize=14)
plt.title('Perceived_Trustworthiness', fontsize=14)
plt.grid()

# %% [markdown]
# Amazon is more Perceived_Trustworthiness than other retailers.

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Online_assistance'])
plt.xlabel('Count', fontsize=14)
plt.ylabel('Online_assistance', fontsize=14)
plt.title('Online_assistance', fontsize=14)
plt.grid()

# %% [markdown]
# Majority of the retailers provide online assitance through multiple channels.

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Longer_logged_in'])
plt.xlabel('Count', fontsize=14)
plt.ylabel('Longer_logged_in', fontsize=14)
plt.title('Longer_logged_in', fontsize=14)
plt.grid()

# %% [markdown]
# Amazon have Longer time to get logged in (promotion, sales period).

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Longer_display_time'])
plt.xlabel('Count', fontsize=14)
plt.ylabel('Longer_display_time', fontsize=14)
plt.title('Longer_display_time', fontsize=14)
plt.grid()

# %% [markdown]
# Amazon and flipcart take Longer time in displaying graphics and photos (promotion, sales period).

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Late_price_declaration'])
plt.xlabel('Count', fontsize=14)
plt.ylabel('Late_price_declaration', fontsize=14)
plt.title('Late_price_declaration', fontsize=14)
plt.grid()

# %% [markdown]
# According to Majoroty of the shoper Myntra having Late declaration of price (promotion, sales period).

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Longer_page_loading'])
plt.xlabel('Count', fontsize=14)
plt.ylabel('Longer_page_loading', fontsize=14)
plt.title('Longer_page_loading', fontsize=14)
plt.grid()

# %% [markdown]
# According to Majoroty of the shoper Myntra having longer page loading time, paytm is at 2nd place.

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Limited_payment_mode'])
plt.xlabel('Count', fontsize=14)
plt.ylabel('Limited_payment_mode', fontsize=14)
plt.title('Limited_payment_mode', fontsize=14)
plt.grid()
locs, labels = plt.xticks(fontsize=14)
plt.setp(labels, rotation=90)
plt.show()

# %% [markdown]
# According to Majoroty of the shoper Snapdeal having Limited_payment_mode.

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Long_delivary_period'])
plt.xlabel('Count', fontsize=14)
plt.ylabel('Long_delivary_period', fontsize=14)
plt.title('Long_delivary_period', fontsize=14)
plt.grid()

# %% [markdown]
# According to Majoroty of the shoper Paytm having Long_delivary_period.

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Change_in_website'])
plt.xlabel('Count', fontsize=14)
plt.ylabel('Change_in_website', fontsize=14)
plt.title('Change_in_website', fontsize=14)
plt.grid()

# %% [markdown]
# Amazon having Change_in_website according to requirements of user.

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Frequent_disruption'])
plt.xlabel('Count', fontsize=14)
plt.ylabel('Frequent_disruption', fontsize=14)
plt.title('Frequent_disruption', fontsize=14)
plt.grid()
locs, labels = plt.xticks(fontsize=14)
plt.setp(labels, rotation=90)
plt.show()

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Efficient_website'])
plt.xlabel('Count', fontsize=14)
plt.ylabel('Efficient_website', fontsize=14)
plt.title('Efficient_website', fontsize=14)
plt.grid()
locs, labels = plt.xticks(fontsize=14)
plt.setp(labels, rotation=90)
plt.show()

# %% [markdown]
# According to majority of shoppers Amazon.in is Efficient website.

# %%
plt.figure(figsize=(8,7))
sns.countplot(y=df1['Recommended_retailers'])
plt.xlabel('Count', fontsize=14)
plt.ylabel('Recommended_retailers', fontsize=14)
plt.title('Recommended_retailers', fontsize=14)
plt.grid()
locs, labels = plt.xticks(fontsize=14)
plt.setp(labels, rotation=90)
plt.show()

# %% [markdown]
# Amazon and Flipcart are most recomended retailers.

# %% [markdown]
# Q2. How many male and female are there in diffrent age group of shoppers?

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='Age', hue='Gender', data=df1)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Age Vs Gender')
plt.grid()

# %% [markdown]
# We can see Maximum shoppers in every age group are females.
# 21-30 Age group is more active in online purcahse.
# Age group 21- 50 years are activily puchaning online as compare to age less than 20 and 51 years above.

# %% [markdown]
# Q3. Visualize number of male and female from diffrent city and check the trend of buying on the basis of male and female.

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='City', hue='Gender', data=df1)
plt.xlabel('City', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('City Vs Gender')
plt.grid()

# %% [markdown]
# We can see in most of the cities Female buyers are more as compare to male.
# Only Delhi and noida having maximum male buyer as compare to females.
# In cities like Moradabad and buladshar we have only male buyers.
# In merrut and Solan we have only female buyers.

# %%
pd.crosstab(df1['City'], df1['Gender'])
# Out:
# Gender         Female  Male
# City
# Bangalore          34     3
# Bulandshahr         0     2
# Delhi              18    40
# Ghaziabad          17     1
# Greater Noida      42     1
# Gurgaon            11     1
# Karnal             20     7
# Merrut              9     0
# Moradabad           0     5
# Noida              12    28
# Solan              18     0

# %% [markdown]
# Q4: Visualize and check Decision makign time with repect to gender.

# %%
sns.catplot(x="Decision_Time", hue="Gender",data=df1, kind="count",height=5, aspect=2)

# %%
pd.crosstab(df1['Decision_Time'], df1['Gender'])
# Out:
# Gender             Female  Male
# Decision_Time
# 1-5 mins               10     4
# 11-15 mins             41     5
# 6-10 mins              27    44
# Less than 1 min        12     3
# more than 15 mins      91    32

# %% [markdown]
# Graph shows relation exploration time before making buying decision and Internet access with respect to gender.
# Most of the girls are taking more exploration time befor making buying decision.

# %% [markdown]
# Q5: What is the recomendation of retailesr made by the online shopers on the basis of gender?

# %%
plt.figure(figsize=(12,8))
sns.countplot(y='Recommended_retailers', hue='Gender', data=df1)
plt.xlabel('Count', fontsize=14)
plt.ylabel('Recommended_retailers', fontsize=14)
plt.title('Recommended_retailers')
plt.grid()

# %%
pd.crosstab(df1['Recommended_retailers'], df1['Gender'])
# Out:
# Gender                                             Female  Male
# Recommended_retailers
# Amazon.in                                              47    32
# Amazon.in, Flipkart.com                                42    20
# Amazon.in, Flipkart.com, Myntra.com                    14     1
# Amazon.in, Myntra.com                                  22     8
# Amazon.in, Paytm.com                                   11     2
# Amazon.in, Paytm.com, Myntra.com                       16     4
# Flipkart.com                                           28    11
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com       1    10

# %% [markdown]
# From above data most of male and females are prefering Amazon and Flipcart is the second app to shop online.

# %%
pd.crosstab(df1['Recommended_retailers'], df1['Abondon_Reason'] )
# Out:
# Abondon_Reason                                     Better alternative offer  \
# Recommended_retailers
# Amazon.in                                                                28
# Amazon.in, Flipkart.com                                                  62
# Amazon.in, Flipkart.com, Myntra.com                                      15
# Amazon.in, Myntra.com                                                    15
# Amazon.in, Paytm.com                                                     13
# Amazon.in, Paytm.com, Myntra.com                                          0
# Flipkart.com                                                              0
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com                         0
#
# Abondon_Reason                                     Change in price  \
# Recommended_retailers
# Amazon.in                                                       29
# Amazon.in, Flipkart.com                                          0
# Amazon.in, Flipkart.com, Myntra.com                              0
# Amazon.in, Myntra.com                                            0
# Amazon.in, Paytm.com                                             0
# Amazon.in, Paytm.com, Myntra.com                                 0
# Flipkart.com                                                     8
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com                0
#
# Abondon_Reason                                     Lack of trust  \
# Recommended_retailers
# Amazon.in                                                      0
# Amazon.in, Flipkart.com                                        0
# Amazon.in, Flipkart.com, Myntra.com                            0
# Amazon.in, Myntra.com                                          0
# Amazon.in, Paytm.com                                           0
# Amazon.in, Paytm.com, Myntra.com                               0
# Flipkart.com                                                  31
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com              0
#
# Abondon_Reason                                     No preferred mode of payment  \
# Recommended_retailers
# Amazon.in                                                                    14
# Amazon.in, Flipkart.com                                                       0
# Amazon.in, Flipkart.com, Myntra.com                                           0
# Amazon.in, Myntra.com                                                         0
# Amazon.in, Paytm.com                                                          0
# Amazon.in, Paytm.com, Myntra.com                                              0
# Flipkart.com                                                                  0
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com                             0
#
# Abondon_Reason                                     Promo code not applicable
# Recommended_retailers
# Amazon.in                                                                  8
# Amazon.in, Flipkart.com                                                    0
# Amazon.in, Flipkart.com, Myntra.com                                        0
# Amazon.in, Myntra.com                                                     15
# Amazon.in, Paytm.com                                                       0
# Amazon.in, Paytm.com, Myntra.com                                          20
# Flipkart.com                                                               0
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com                         11

# %%
pd.crosstab(df1['Recommended_retailers'], df1['Speedy_delivery'] )
# Out:
# Speedy_delivery                                    Amazon.in  \
# Recommended_retailers
# Amazon.in                                                 47
# Amazon.in, Flipkart.com                                    0
# Amazon.in, Flipkart.com, Myntra.com                        0
# Amazon.in, Myntra.com                                     15
# Amazon.in, Paytm.com                                      13
# Amazon.in, Paytm.com, Myntra.com                          20
# Flipkart.com                                              12
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com          0
#
# Speedy_delivery                                    Amazon.in, Flipkart.com  \
# Recommended_retailers
# Amazon.in                                                               11
# Amazon.in, Flipkart.com                                                 37
# Amazon.in, Flipkart.com, Myntra.com                                      0
# Amazon.in, Myntra.com                                                   15
# Amazon.in, Paytm.com                                                     0
# Amazon.in, Paytm.com, Myntra.com                                         0
# Flipkart.com                                                            19
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com                        0
#
# Speedy_delivery                                    Amazon.in, Flipkart.com, Myntra.com  \
# Recommended_retailers
# Amazon.in                                                                            0
# Amazon.in, Flipkart.com                                                              0
# Amazon.in, Flipkart.com, Myntra.com                                                 15
# Amazon.in, Myntra.com                                                                0
# Amazon.in, Paytm.com                                                                 0
# Amazon.in, Paytm.com, Myntra.com                                                     0
# Flipkart.com                                                                         0
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com                                    0
#
# Speedy_delivery                                    Amazon.in, Flipkart.com, Snapdeal.com  \
# Recommended_retailers
# Amazon.in                                                                              0
# Amazon.in, Flipkart.com                                                               25
# Amazon.in, Flipkart.com, Myntra.com                                                    0
# Amazon.in, Myntra.com                                                                  0
# Amazon.in, Paytm.com                                                                   0
# Amazon.in, Paytm.com, Myntra.com                                                       0
# Flipkart.com                                                                           0
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com                                     11
#
# Speedy_delivery                                    Flipkart.com  \
# Recommended_retailers
# Amazon.in                                                     7
# Amazon.in, Flipkart.com                                       0
# Amazon.in, Flipkart.com, Myntra.com                           0
# Amazon.in, Myntra.com                                         0
# Amazon.in, Paytm.com                                          0
# Amazon.in, Paytm.com, Myntra.com                              0
# Flipkart.com                                                  8
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com             0
#
# Speedy_delivery                                    Flipkart.com, Myntra.com, Snapdeal.com
# Recommended_retailers
# Amazon.in                                                                              14
# Amazon.in, Flipkart.com                                                                 0
# Amazon.in, Flipkart.com, Myntra.com                                                     0
# Amazon.in, Myntra.com                                                                   0
# Amazon.in, Paytm.com                                                                    0
# Amazon.in, Paytm.com, Myntra.com                                                        0
# Flipkart.com                                                                            0
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com                                       0

# %% [raw]
# Observation :
# We already Know more than 90% Customer thinks that gaurantee on privacy of thier information is important for them.Majority of customers trust Amazon.in more than other shopping platform for Privacy of customers’ information
# Majority of customer trust Amazon.in followed by Flipkart.in over Security of thier financial information.We also see very few peoples trust payment platform paytm.
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com provide assistance through different multi channel.
# Longer time to get logged in can annoyed customer. Amazon.in take longer time to logged in while Flipkart.com take least time among all.
# Majority of people agree that Amazon.in, Flipkart.com takes longer time in displaying and photos.
# Myntra.com followed by Paytm.com take longer page loading time.
# Most of people want shorter delivery time frame, majority customer agree that Paytm.com takes longest time for delivery compare to others.
# Amazon.in website is as effient as ealier after updation.
# Majority 80 peoples recommanded Amazon.in to their friends.
